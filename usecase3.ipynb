# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
# %matplotlib inline

# %%
## Loading the data
#We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
wru_ranking = pd.read_csv("/Users/raneemaj/Documents/GitHub/Use-case3/data/Word Rank University.csv")

# %%
wru_ranking.head(10)
# Out:
#    World Rank                                   University Names  \
# 0   1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1   2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2   3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3   4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4   5Top 0.1%  University of Oxford\n  Education: A+; Employa...
# 5   6Top 0.1%  Princeton University\n  Education: A+; Employa...
# 6   7Top 0.1%  University of Chicago\n  Education: A+; Employ...
# 7   8Top 0.1%  Columbia University\n  Education: A+; Employab...
# 8   9Top 0.1%  University of Pennsylvania\n  Education: A; Em...
# 9  10Top 0.1%  Yale University\n  Education: A+; Employabilit...
#
#         Location   National Rank Educational Rank Employability Rank  \
# 0             USA              1                1                  1
# 1             USA              2                4                 12
# ...

# %%
wru_ranking.dtypes
# Out:
# World Rank             object
# University Names       object
# Location               object
# National Rank           int64
# Educational Rank       object
# Employability Rank     object
# Faculty Rank           object
# Research Rank          object
# Score                 float64
# dtype: object

# %%
wru_ranking.isnull().sum()
# Out:
# World Rank            0
# University Names      0
# Location              0
# National Rank         0
# Educational Rank      0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# dtype: int64

# %%
wru_ranking.tail()
# Out:
#         World Rank                       University Names Location   \
# 1995  1996Top 9.8%          Chongqing Jiaotong University     China
# 1996  1997Top 9.8%  University of Arkansas at Little Rock       USA
# 1997  1998Top 9.8%             Van Yüzüncü Yıl University    Turkey
# 1998  1999Top 9.8%               Bharathidasan University     India
# 1999  2000Top 9.8%             Gebze Technical University    Turkey
#
#       National Rank Educational Rank Employability Rank Faculty Rank  \
# 1995            314                -                  -            -
# 1996            332                -               1322            -
# 1997             54                -                  -            -
# 1998             64                -                  -            -
# 1999             55                -                  -            -
#
#      Research Rank  Score
# 1995          1917   66.0
# 1996          1920   66.0
# 1997          1919   66.0
# 1998          1922   66.0
# ...

# %%
#wru_ranking.sum()

# %%
(wru_ranking['National Rank']=='-').sum()
# Out:
# 0

# %%
(wru_ranking['Educational Rank']=='-').sum()
# Out:
# 1562

# %%
(wru_ranking['Employability Rank']=='-').sum()
# Out:
# 967

# %%
(wru_ranking['Faculty Rank']=='-').sum()
# Out:
# 1727

# %%
(wru_ranking['Research Rank']=='-').sum()
# Out:
# 66

# %%
(wru_ranking['Score']=='-').sum()
# Out:
# 0

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
# sorting the data set

# %%
wru_ranking_sorted= wru_ranking.sort_values(by='National Rank')

# %%
pd.set_option('display.max_rows', 100)

# %%
# #ranking in uk
# wru_ranking_sorted= wru_ranking.sort_values(by='National Rank')
# us_ranking=wru_ranking[wru_ranking['Locat'] == 'USA'].head(100)
# us_ranking
# #uk_ranking.shape
# #(us_ranking['Educational Rank']=='-').sum()

# %%
wru_ranking_sorted= wru_ranking.sort_values(by='National Rank')
wru_ranking[wru_ranking['Locat'] == 'Saudi Arabia'].head(100)
# Out:
#         World Rank                                   University Names  \
# 244    245Top 1.2%                          King Abdulaziz University
# 278    279Top 1.4%  King Abdullah University of Science and Techno...
# 351    352Top 1.8%                               King Saud University
# 656    657Top 3.3%     King Fahd University of Petroleum and Minerals
# 1310  1311Top 6.4%  King Saud bin Abdulaziz University for Health ...
# 1446  1447Top 7.1%                             King Khalid University
# 1508  1509Top 7.4%                                    Taif University
# 1546  1547Top 7.6%             Imam Abdulrahman Bin Faisal University
# 1585  1586Top 7.8%                                  Taibah University
# 1710  1711Top 8.4%             Prince Sattam Bin Abdulaziz University
# 1741  1742Top 8.5%                             Umm Al-Qura University
# 1761  1762Top 8.6%                                Alfaisal University
# ...

# %%
#top 100 uninversity
wru_ranking.head(100)
# Out:
#      World Rank                                   University Names  \
# 0     1Top 0.1%  Harvard University\n  CWUR Rating System:   Ed...
# 1     2Top 0.1%  Massachusetts Institute of Technology\n  Educa...
# 2     3Top 0.1%  Stanford University\n  Education: A+; Employab...
# 3     4Top 0.1%  University of Cambridge\n  Education: A+; Empl...
# 4     5Top 0.1%  University of Oxford\n  Education: A+; Employa...
# 5     6Top 0.1%  Princeton University\n  Education: A+; Employa...
# 6     7Top 0.1%  University of Chicago\n  Education: A+; Employ...
# 7     8Top 0.1%  Columbia University\n  Education: A+; Employab...
# 8     9Top 0.1%  University of Pennsylvania\n  Education: A; Em...
# 9    10Top 0.1%  Yale University\n  Education: A+; Employabilit...
# 10   11Top 0.1%  California Institute of Technology\n  Educatio...
# 11   12Top 0.1%  University of California, Berkeley\n  Educatio...
# 12   13Top 0.1%                                University of Tokyo
# ...

# %%
top_100=wru_ranking.head(100)
top_100[top_100['Faculty Rank'] == '-'].head(100)
# wru_ranking[wru_ranking['Educational Rank'] == '-'].head(100)
# Out:
#     World Rank                           University Names      Locat  \
# 43  44Top 0.3%                        Tsinghua University      China
# 48  49Top 0.3%                          Peking University      China
# 54  55Top 0.3%  University of Chinese Academy of Sciences      China
# 73  74Top 0.4%              Shanghai Jiao Tong University      China
# 80  81Top 0.4%           National University of Singapore  Singapore
# 84  85Top 0.5%                        Zhejiang University      China
# 88  89Top 0.5%                           Fudan University      China
# 91  92Top 0.5%                       University of Sydney  Australia
#
#     National Rank Educational Rank Employability Rank Faculty Rank  \
# 43              1              346                 56            -
# 48              2              369                 58            -
# 54              3                -               1304            -
# 73              4                -                140            -
# ...

# %%
top_100=wru_ranking.head(100)
top_100[top_100['Research Rank'] == '-'].head(100)
# Out:
# Empty DataFrame
# Columns: [World Rank, University Names, Locat, National Rank, Educational Rank, Employability Rank, Faculty Rank, Research Rank, Score]
# Index: []

# %%
top_100=wru_ranking.head(100)
top_100[top_100['Employability Rank'] == '-'].head(100)
# Out:
#     World Rank                                 University Names   Locat  \
# 37  38Top 0.2%                             Karolinska Institute  Sweden
# 60  61Top 0.3%                           Rockefeller University     USA
# 72  73Top 0.4%  University of Texas Southwestern Medical Center     USA
# 86  87Top 0.5%                    Weizmann Institute of Science  Israel
#
#     National Rank Educational Rank Employability Rank Faculty Rank  \
# 37              1               39                  -           35
# 60             33               13                  -            8
# 72             41               41                  -           42
# 86              2               24                  -           51
#
#    Research Rank  Score
# 37            62   85.8
# 60           460   83.9
# 72           167   83.2
# 86           289   82.4

# %%
top_100=wru_ranking.head(100)
top_100[top_100['Educational Rank'] == '-'].head(100)
# Out:
#     World Rank                           University Names        Locat  \
# 35  36Top 0.2%    University of California, San Francisco          USA
# 54  55Top 0.3%  University of Chinese Academy of Sciences        China
# 68  69Top 0.4%      Texas A&M University, College Station          USA
# 73  74Top 0.4%              Shanghai Jiao Tong University        China
# 84  85Top 0.5%                        Zhejiang University        China
# 95  96Top 0.5%   École Polytechnique Fédérale de Lausanne  Switzerland
#
#     National Rank Educational Rank Employability Rank Faculty Rank  \
# 35             23                -               1554           15
# 54              3                -               1304            -
# 68             39                -                129           72
# 73              4                -                140            -
# 84              5                -                351            -
# ...

# %%
#
# now lets navigate in times ranking
#
#
#
#
#

# %%
times_ranking=pd.read_csv("/Users/raneemaj/Documents/GitHub/Use-case3/data/Times Higher Education.csv")

# %%
times_ranking.head(10)
# Out:
#   Rank                  University Name   \
# 0    1         Western Sydney University
# 1    2          University of Manchester
# 2    3                Queen’s University
# 3    4         Universiti Sains Malaysia
# 4    5            University of Tasmania
# 5    6  Arizona State University (Tempe)
# 6    7             University of Alberta
# 7    7                   RMIT University
# 8    9                Aalborg University
# 9    9            University of Victoria
#
#                       ranking-institution-title href        Location  \
# 0  https://www.timeshighereducation.com/world-uni...       Australia
# 1  https://www.timeshighereducation.com/world-uni...  United Kingdom
# 2  https://www.timeshighereducation.com/world-uni...          Canada
# 3  https://www.timeshighereducation.com/world-uni...        Malaysia
# 4  https://www.timeshighereducation.com/world-uni...       Australia
# 5  https://www.timeshighereducation.com/world-uni...   United States
# ...

# %%
times_ranking.dtypes
# Out:
# Rank                               object
# University Name                    object
# ranking-institution-title href     object
# Location                           object
# sdg-score-multi__number           float64
# sdg-score-multi__value             object
# sdg-score-multi__number 2         float64
# sdg-score-multi__value 2           object
# sdg-score-multi__number 3         float64
# sdg-score-multi__value 3           object
# sdg-score-multi__value 4           object
# scores                             object
# sdg-score-multi__number 5         float64
# sdg-score-multi__value 5           object
# sdg-score-multi__number 6         float64
# sdg-score-multi__value 6           object
# sdg-score-multi__number 7         float64
# sdg-score-multi__value 7           object
# sdg-score-multi__number 8         float64
# sdg-score-multi__value 8           object
# dtype: object

# %%
times_ranking[times_ranking['Location'].isnull()]
# Out:
#           Rank                                   University Name   \
# 248    201–300                           Kazan Federal University
# 276    201–300  Peter the Great St Petersburg Polytechnic Univ...
# 285    201–300                                    RUDN University
# 303    301–400                             Altai State University
# 310    301–400           Bauman Moscow State Technical University
# 346    301–400     Irkutsk National Research Technical University
# 366    301–400         National Research Nuclear University MEPhI
# 455    401–600  Financial University under the Government of t...
# 463    401–600            Immanuel Kant Baltic Federal University
# 471    401–600                                    ITMO University
# 487    401–600                     Kursk State Medical University
# 506    401–600  Moscow Institute of Physics and Technology (MIPT)
# 507    401–600      Russian Biotechnological University (BIOTECH)
# ...

# %%
times_ranking.isnull().sum()
# Out:
# Rank                                 0
# University Name                      0
# ranking-institution-title href      91
# Location                            91
# sdg-score-multi__number            724
# sdg-score-multi__value             724
# sdg-score-multi__number 2          765
# sdg-score-multi__value 2           766
# sdg-score-multi__number 3          779
# sdg-score-multi__value 3           786
# sdg-score-multi__value 4             8
# scores                               0
# sdg-score-multi__number 5         1026
# sdg-score-multi__value 5          1034
# sdg-score-multi__number 6         1093
# sdg-score-multi__value 6          1095
# sdg-score-multi__number 7         1152
# sdg-score-multi__value 7          1152
# sdg-score-multi__number 8         1108
# sdg-score-multi__value 8          1108
# dtype: int64

# %%
# fill the Nan with "Unknown" so that i can deal with it in the coming steps
times_ranking["Location"]=times_ranking["Location"].fillna("Unknown")

# %%
# to make sure that i gor rid of the Nan
times_ranking.isnull().sum()
# Out:
# Rank                                 0
# University Name                      0
# ranking-institution-title href      91
# Location                             0
# sdg-score-multi__number            724
# sdg-score-multi__value             724
# sdg-score-multi__number 2          765
# sdg-score-multi__value 2           766
# sdg-score-multi__number 3          779
# sdg-score-multi__value 3           786
# sdg-score-multi__value 4             8
# scores                               0
# sdg-score-multi__number 5         1026
# sdg-score-multi__value 5          1034
# sdg-score-multi__number 6         1093
# sdg-score-multi__value 6          1095
# sdg-score-multi__number 7         1152
# sdg-score-multi__value 7          1152
# sdg-score-multi__number 8         1108
# sdg-score-multi__value 8          1108
# dtype: int64

# %%
#### stoooooooooooooooooooop analysis!!!!!!!!!!!
#
#
#
#
#
#
#
#
#
#

# %%
times24=pd.read_csv("/Users/raneemaj/Documents/GitHub/Use-case3/data/TIMES_WorldUniversityRankings_2024.csv")

# %%
times24.head()
# Out:
#   rank                                   name scores_overall  \
# 0    1                   University of Oxford           98.5
# 1    2                    Stanford University           98.0
# 2    3  Massachusetts Institute of Technology           97.9
# 3    4                     Harvard University           97.8
# 4    5                University of Cambridge           97.5
#
#    scores_overall_rank  scores_teaching  scores_teaching_rank  \
# 0                   10             96.6                     5
# 1                   20             99.0                     1
# 2                   30             98.6                     2
# 3                   40             97.7                     3
# 4                   50             95.8                     7
#
#    scores_research  scores_research_rank  scores_citations  \
# 0            100.0                     2              99.0
# 1             97.8                     8              99.6
# ...

# %%
times24.isnull().sum()
# Out:
# rank                                    0
# name                                    0
# scores_overall                        769
# scores_overall_rank                     0
# scores_teaching                       769
# scores_teaching_rank                    0
# scores_research                       769
# scores_research_rank                    0
# scores_citations                      769
# scores_citations_rank                   0
# scores_industry_income                769
# scores_industry_income_rank             0
# scores_international_outlook          769
# scores_international_outlook_rank       0
# record_type                             0
# member_level                            0
# url                                     0
# nid                                     0
# location                                0
# stats_number_students                   0
# stats_student_staff_ratio               0
# stats_pc_intl_students                  0
# ...

# %%
#checking the buttom of dataset
times24_tail800=times24.tail(800)

# %%
times24_tail800.isnull().sum()
# Out:
# rank                                   0
# name                                   0
# scores_overall                       769
# scores_overall_rank                    0
# scores_teaching                      769
# scores_teaching_rank                   0
# scores_research                      769
# scores_research_rank                   0
# scores_citations                     769
# scores_citations_rank                  0
# scores_industry_income               769
# scores_industry_income_rank            0
# scores_international_outlook         769
# scores_international_outlook_rank      0
# record_type                            0
# member_level                           0
# url                                    0
# nid                                    0
# location                               0
# stats_number_students                  0
# stats_student_staff_ratio              0
# stats_pc_intl_students                 0
# stats_female_male_ratio               16
# ...

# %%
# i need to rename one of the column in order to merge them 
times24.rename(columns={'name': 'University Name'}, inplace=True)



times_ranking.rename(columns={'University Name ': 'University Name'}, inplace=True)
print(times_ranking.columns)
# Out:
# Index(['Rank', 'University Name', 'ranking-institution-title href', 'Location',
#        'sdg-score-multi__number', 'sdg-score-multi__value',
#        'sdg-score-multi__number 2', 'sdg-score-multi__value 2',
#        'sdg-score-multi__number 3', 'sdg-score-multi__value 3',
#        'sdg-score-multi__value 4', 'scores', 'sdg-score-multi__number 5',
#        'sdg-score-multi__value 5', 'sdg-score-multi__number 6',
#        'sdg-score-multi__value 6', 'sdg-score-multi__number 7',
#        'sdg-score-multi__value 7', 'sdg-score-multi__number 8',
#        'sdg-score-multi__value 8'],
#       dtype='object')

# %%
location_column = 'Location'

# Merge the datasets based on the location column
merged_df = pd.merge(times_ranking , times24, on='University Name', how='inner')
#column_to_compare = 'Location'
#comparison_result = merged_df['University Name' + column_to_compare] > merged_df['University Name' + column_to_compare]

# %%
#start_column = 'sdg-score-multi__number 5'
#end_column = 'sdg-score-multi__value 8'

# Get the index positions of the start and end columns
#start_index =merged_df.columns.get_loc(start_column)
#end_index = merged_df.columns.get_loc(end_column)

# Drop the columns between the start and end positions
#merged_df.drop(merged_df.columns[start_index:end_index+1], axis=1, inplace=True)
merged_df
# Out:
#        Rank                        University Name  \
# 0         1              Western Sydney University
# 1         2               University of Manchester
# 2         3                     Queen’s University
# 3         4              Universiti Sains Malaysia
# 4         5                 University of Tasmania
# ...     ...                                    ...
# 1271  1001+            Yogyakarta State University
# 1272  1001+                       Zarqa University
# 1273  1001+  Zewail City of Science and Technology
# 1274  1001+                   University of Žilina
# 1275  1001+     Zonguldak Bülent Ecevit University
#
#                          ranking-institution-title href        Location  \
# 0     https://www.timeshighereducation.com/world-uni...       Australia
# 1     https://www.timeshighereducation.com/world-uni...  United Kingdom
# 2     https://www.timeshighereducation.com/world-uni...          Canada
# ...

# %%
times_ranking.dtypes
# Out:
# Rank                               object
# University Name                    object
# ranking-institution-title href     object
# Location                           object
# sdg-score-multi__number           float64
# sdg-score-multi__value             object
# sdg-score-multi__number 2         float64
# sdg-score-multi__value 2           object
# sdg-score-multi__number 3         float64
# sdg-score-multi__value 3           object
# sdg-score-multi__value 4           object
# scores                             object
# sdg-score-multi__number 5         float64
# sdg-score-multi__value 5           object
# sdg-score-multi__number 6         float64
# sdg-score-multi__value 6           object
# sdg-score-multi__number 7         float64
# sdg-score-multi__value 7           object
# sdg-score-multi__number 8         float64
# sdg-score-multi__value 8           object
# dtype: object

# %%
times24.dtypes
# Out:
# rank                                  object
# University Name                       object
# scores_overall                        object
# scores_overall_rank                    int64
# scores_teaching                      float64
# scores_teaching_rank                   int64
# scores_research                      float64
# scores_research_rank                   int64
# scores_citations                     float64
# scores_citations_rank                  int64
# scores_industry_income               float64
# scores_industry_income_rank            int64
# scores_international_outlook         float64
# scores_international_outlook_rank      int64
# record_type                           object
# member_level                           int64
# url                                   object
# nid                                    int64
# location                              object
# stats_number_students                 object
# stats_student_staff_ratio            float64
# ...

# %%
pd.set_option('display.max_columns', 50)
